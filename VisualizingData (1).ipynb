# %%
import os

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path = "/content/drive/MyDrive/MentalHealth"

# %%
from posix import chdir
chdir(path)
# !ls
# Out:
#  data_cleaning.py	'filtered_Mental_Health (1).csv'  'output images'
#  data.csv		 Graghical_reprentation.py	   __pycache__
#  data_frame_info.ipynb	'__init()__.py'			   survey.csv
#  data_frame_info.py	 mental_health_info.py		   treatment.png

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
mh_fdf = pd.read_csv("/content/drive/MyDrive/MentalHealth/filtered_Mental_Health (1).csv")

# %%
par = mh_fdf['treatment'].value_counts(normalize=True).rename_axis('treatment').reset_index(name = 'percentage')
print(par)
plt.title('Number of Employees who wants to take Treatment')
ax = sns.barplot(x = 'treatment', y = 'percentage', data = par, palette='Set2')
plt.savefig('/content/drive/MyDrive/MentalHealth/output images/treatment')
plt.show
# Out:
#   treatment  percentage
# 0       Yes    0.504785
# 1        No    0.495215
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# par.groupby('treatment').sum().plot(kind='pie', subplots=True)

# %%
def cal_per(col):
  percentage = col.value_counts(normalize=True).rename_axis(col.name).reset_index(name = 'percentage')
  return percentage

# %%
from matplotlib.cbook import file_requires_unicode
def pl_fig(col, title1, title2):
  plt.figure(figsize = (15,4))
  # plt.subplot(1,2,1)
  per = cal_per(col)

  mh_fdf.groupby(col).sum().plot(kind='pie', subplots=True,colormap='Set2', figsize = (10, 5), autopct = '%1.1f%%')
  plt.legend(bbox_to_anchor=(1, 0.5), loc="center left")
  plt.title(title1)
  plt.show()
  # sns.barplot(x = col.name, y = 'percentage', data = per,palette='Set1')
  # plt.subplot(1,2,2)
  plt.title(title2)
  sns.countplot(x = col, y=None , hue=mh_fdf['treatment'],palette='Set2')
  plt.xticks(rotation=45)
  # folder_path = '/content/drive/MyDrive/MentalHealth/output images'
  # plt.savefig(f'{folder_path}/{col.name}')
  plt.show()

# %%
title1 = 'Employement type of respondents'
title2 = 'Employement type of respondents who are seeking treatment'
pl_fig(mh_fdf['self_employed'],title1, title2)

# %%
title1 = 'Family history of respondants'
title2 = 'Family history of respondants who are seeking treatment'
pl_fig(mh_fdf['family_history'],title1, title2)

# %%
title1 = 'work_interfere of respondants'
title2 = 'work_interfere of respondants who are seeking treatment'
pl_fig(mh_fdf['work_interfere'],title1, title2)

# %%
title1 = 'working type of respondants'
title2 = 'working type of respondants who are seeking treatment'
pl_fig(mh_fdf['remote_work'],title1, title2)

# %%
title1 = 'company (tech/non-tech) type of respondants'
title2 = 'company (tech/non-tech) type of respondants who are seeking treatment'
pl_fig(mh_fdf['tech_company'],title1, title2)

# %%
title1 = 'Benefits given to the employees'
title2 = 'Benefits given to the employees who are seeking treatment'
pl_fig(mh_fdf['benefits'],title1, title2)

# %%
title1 = 'Mental Healthcare provided to the employees'
title2 = 'Mental Healthcare provided who are seeking treatment'
pl_fig(mh_fdf['care_options'],title1, title2)

# %%
title1 = 'Mental Health in wellness program given to the employees'
title2 = 'Mental Health in wellness program given who are seeking treatment'
pl_fig(mh_fdf['wellness_program'],title1, title2)

# %%
title1 = 'Anonymity for mental health given to the employees'
title2 = 'Anonymity for mental health given to the employees who are seeking treatment'
pl_fig(mh_fdf['anonymity'],title1, title2)

# %%
title1 = 'Leave for mental health given to the employees'
title2 = 'Leave for mental health given to the employees who are seeking treatment'
pl_fig(mh_fdf['leave'],title1, title2)

# %%
title1 = 'Consequence of discussing mental health to employer'
title2 = 'Consequence of discussing about MH who are seeking treatment'
pl_fig(mh_fdf['mental_health_consequence'],title1, title2)

# %%
title1 = 'Consequence of discussing Physical health to employer'
title2 = 'Consequence of discussing about PH who are seeking treatment'
pl_fig(mh_fdf['phys_health_consequence'],title1, title2)

# %%
title1 = 'Discussing mental health with coworkers'
pl_fig(mh_fdf['coworkers'],title1, title1)

# %%
title1 = 'Discussing mental health with supervisor'
pl_fig(mh_fdf['supervisor'],title1, title1)

# %%
title1 = 'Discussing mental health with mental health interviewer'
pl_fig(mh_fdf['mental_health_interview'],title1, title1)

# %%
title1 = 'Discussing Pysical health with mental health interviewer'
pl_fig(mh_fdf['phys_health_interview'],title1, title1)

# %%
title1 = "Mental health vs Pysical health"
pl_fig(mh_fdf['mental_vs_physical'],title1, title1)

# %%
title1 = 'Consequence observed for disclosing the mental health'
pl_fig(mh_fdf['obs_consequence'],title1, title1)
